# %% [markdown]
# # 🔬 Notebook 06: 3D ViT + Hybrid UNETR From-Scratch Ablation
# ### Scientific Representation Learning Baseline (Zero Pre-Training)
#
# This dedicated notebook runs the **3D ViT + Hybrid UNETR Decoder Trained From Scratch** ablation baseline:
# 1. **Scientific Question**: Isolates whether 3D VisReg JEPA's volumetric segmentation performance is driven by self-supervised representation learning ($\Delta_{\text{JEPA}}$) or purely by the high parameter capacity and multi-scale inductive bias of the 3D ViT-FPN architecture.
# 2. **Zero Pre-Trained Weights Required**: Model is initialized completely from random weights with a deterministic seed (`--from_scratch`). No pre-trained checkpoint upload is needed!
# 3. **Supervised 30-Epoch Training**: Trains 3D ViT-FPN end-to-end using combined Soft Dice and Binary Cross-Entropy (BCE) loss.
# 4. **Held-Out Test Set Evaluation**: Measures exact 3D Dice, IoU, 95th Percentile Hausdorff Distance (mm), and inference latency.
# 5. **Artifact Export**: Packages checkpoints and metrics into `vit_scratch_outputs.zip` for 1-click download and local master comparison.
#
# > **Estimated Runtime**: ~1.2 - 1.8 hours on NVIDIA Tesla T4 GPU (accelerated by the $18.7\times$ fast validation engine).

# %% [markdown]
# ## 1. Hardware & CUDA Environment Verification

# %%
import datetime
import time

NOTEBOOK_START_TIME = time.time()
NOTEBOOK_START_STR = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
print(f"⏱️ Session Start Time: {NOTEBOOK_START_STR}")

# !nvidia-smi

import torch

print(f"PyTorch Version:  {torch.__version__}")
print(f"CUDA Available:   {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"Device Name:      {torch.cuda.get_device_name(0)}")
    print(f"Total VRAM:       {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB")
else:
    print(
        "WARNING: No GPU detected. Please navigate to Notebook Settings -> Accelerator -> GPU T4!"
    )
# Out:
# ⏱️ Session Start Time: 2026-09-21 00:06:09
# Mon Sep 21 00:06:09 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.159.04             Driver Version: 580.159.04     CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Tesla T4                       Off |   00000000:00:05.0 Off |                    0 |
# | N/A   42C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+
# PyTorch Version:  2.10.0+cu128
# CUDA Available:   True
# Device Name:      Tesla T4
# Total VRAM:       15.64 GB

# %%
# =========================================================================
# ⚙️ Experiment Configuration & Reproducibility Parameters
# =========================================================================

SEED = 42                 # Deterministic seed for weight init, augmentations, and data splits
NUM_WORKERS = 4          # Parallel CPU data loading workers (Kaggle T4 provides 4 vCPUs)
BATCH_SIZE = 2           # Volumetric batch size for 3D ViT-FPN downstream training

# Belt-and-suspenders: pin the mounted full-pool dataset so every script
# resolving the default name finds it even without an explicit data_dir.
import os as _os
from pathlib import Path as _Path
_kaggle_full = _Path("/kaggle/input/brats-3d-full/brats_gli_3d_full")
if _kaggle_full.is_dir() and (_kaggle_full / "metadata.csv").exists():
    _os.environ["BRATS3D_DATA_DIR"] = str(_kaggle_full)
    print(f"Dataset env override: BRATS3D_DATA_DIR={_kaggle_full}")

# %% [markdown]
# ## 2. Dependencies Installation

# %%
# !pip install -q --no-cache-dir monai nibabel tabulate matplotlib
import monai
import nibabel as nib
import tabulate

print(f"✓ MONAI Version:    v{monai.__version__}")
print(f"✓ NiBabel Version:  v{nib.__version__}")
print(f"✓ Tabulate Version: v{tabulate.__version__}")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 136.5 MB/s eta 0:00:00
# ✓ MONAI Version:    v1.6.0
# ✓ NiBabel Version:  v5.4.2
# ✓ Tabulate Version: v0.9.0

# %% [markdown]
# ## 3. Codebase Setup & Editable Installation

# %%
import os
import shutil
import sys
from pathlib import Path

# Setup working directory in /kaggle/working
REPO_URL = "https://github.com/hanriman/tumor_segmentation_3d.git"
work_dir = Path("/kaggle/working/tumor_segmentation_3d")

# Clean up broken or incomplete clone from previous failed runs
if work_dir.exists() and not (work_dir / "src" / "brats_jepa_3d").exists():
    print("⚠️ Cleaning up incomplete repository clone...")
    shutil.rmtree(work_dir)

thesis_repo = Path("/kaggle/working/thesis_repo")
if thesis_repo.exists() and not (thesis_repo / "src" / "brats_jepa_3d").exists():
    shutil.rmtree(thesis_repo)

# Clone repository if not already present
if not (work_dir / "src" / "brats_jepa_3d").exists():
    if (thesis_repo / "src" / "brats_jepa_3d").exists():
        work_dir = thesis_repo
    elif Path("/kaggle/working/src/brats_jepa_3d").exists():
        work_dir = Path("/kaggle/working")
    else:
        print(f"Cloning codebase from: {REPO_URL} ...")
        # !git clone {REPO_URL} {work_dir}

# Verify package was successfully cloned
src_dir = work_dir / "src"
if not (src_dir / "brats_jepa_3d").exists():
    raise RuntimeError(
        "❌ Clone failed! The package 'brats_jepa_3d' was not found on disk.\n"
        "👉 Please ensure 'Internet' is toggled ON in the Kaggle notebook settings (right sidebar)!"
    )

# Change working directory and update sys.path
os.chdir(str(work_dir))
# %cd {work_dir}

if str(src_dir) not in sys.path:
    sys.path.insert(0, str(src_dir))

# Install in editable mode
# !pip install -q -e .

print(f"\n✓ Working directory set to: {Path.cwd()}")
# !git log -1 --oneline 2>/dev/null || echo "(Git commit info unavailable)"
# Out:
# Cloning codebase from: https://github.com/hanriman/tumor_segmentation_3d.git ...
# Cloning into '/kaggle/working/tumor_segmentation_3d'...
# remote: Enumerating objects: 652, done.
# remote: Counting objects: 100% (652/652), done.
# remote: Compressing objects: 100% (289/289), done.
# remote: Total 652 (delta 405), reused 588 (delta 341), pack-reused 0 (from 0)
# Receiving objects: 100% (652/652), 6.12 MiB | 40.71 MiB/s, done.
# Resolving deltas: 100% (405/405), done.
# /kaggle/working
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
#   Building editable for brats-jepa-3d (pyproject.toml) ... done
#
# ✓ Working directory set to: /kaggle/working/tumor_segmentation_3d
# c0954ab (HEAD -> main, origin/main, origin/HEAD) add decoder tag to low lable and ood

# %% [markdown]
# ## 4. Dataset Discovery & Health Checks
# Verifies whether processed `.npz` volumes exist across Kaggle input mounts. If preprocessed data is absent, checks for raw BraTS data and automatically invokes `prepare_data_3d.py`.

# %%
import pandas as pd
import torch

from brats_jepa_3d.config import get_dataset_dir, get_metadata_path
from brats_jepa_3d.data import BraTS3DDataset

print("=== DATASET DISCOVERY ===")
data_dir = get_dataset_dir("brats_gli_3d_full")
meta_path = get_metadata_path("brats_gli_3d_full")
print(f"Dataset Directory: {data_dir} (Exists: {data_dir.exists()})")
print(f"Metadata CSV:      {meta_path} (Exists: {meta_path.exists()})")

# If preprocessed dataset is not found, check for raw BraTS data and run prepare_data_3d.py
if not meta_path.exists():
    print("\n⚠️ Preprocessed dataset not found. Checking for raw BraTS data...")
    # !python scripts/prepare_data_3d.py --limit 100 --dtype float16 --num_workers {NUM_WORKERS} --seed {SEED}
    meta_path = get_metadata_path("brats_gli_3d_full")

if meta_path.exists():
    df = pd.read_csv(meta_path)
    print(f"\n✓ Loaded Metadata: {len(df)} total records across splits:")
    print(df["split"].value_counts().to_string())

    ds = BraTS3DDataset(data_dir=data_dir, split="train")
    sample = ds[0]
    print("\n✓ Sample Tensor Verification:")
    print(f"  Image Shape: {sample['image'].shape} (dtype: {sample['image'].dtype})")
    print(f"  Mask Shape:  {sample['mask'].shape} (dtype: {sample['mask'].dtype})")
    print(f"  Tumor Voxels: {int((sample['mask'] > 0).sum()):,}")
else:
    print(
        "❌ ERROR: Please attach 'brats-3d-full' or raw BraTS dataset via '+ Add Input' in Kaggle!"
    )
# Out:
# === DATASET DISCOVERY ===
# Dataset Directory: /kaggle/input/datasets/rightfel/brats-2024-3d-full/brats_gli_3d_full (Exists: True)
# Metadata CSV:      /kaggle/input/datasets/rightfel/brats-2024-3d-full/brats_gli_3d_full/metadata.csv (Exists: True)
#
# ✓ Loaded Metadata: 1621 total records across splits:
# split
# train    1144
# test      242
# val       235
#
# ✓ Sample Tensor Verification:
#   Image Shape: torch.Size([4, 128, 128, 128]) (dtype: torch.float32)
#   Mask Shape:  torch.Size([1, 128, 128, 128]) (dtype: torch.float32)
#   Tumor Voxels: 19,840

# %% [markdown]
# ## 5. Supervised 3D ViT-FPN Training From Scratch (30 Epochs, AMP)
# Trains the 3D Vision Transformer backbone + Hybrid UNETR decoder **from random initialization** without loading any pre-trained SSL weights (`--from_scratch`).
#
# - **Encoder**: 3D ViT (Patch size $16^3$, Embedding dim $384$, Depth $8$, Heads $6$)
# - **Decoder**: Multi-Scale FPN ($L_2, L_4, L_6, L_8$ progressive upsampling)
# - **Loss**: Combined Soft Dice + BCE Loss
# - **Validation Speed**: Fast 2.4s validation per epoch via decoupled HD95 calculation.

# %%
# !python scripts/train_downstream_3d.py \
    --model_type visreg_jepa \
    --decoder_type unetr_hybrid \
    --from_scratch \
    --seed {SEED} \
    --epochs 3 \
    --batch_size {BATCH_SIZE} \
    --num_workers {NUM_WORKERS} \
    --learning_rate 3e-4 \
    --weight_decay 1e-4 \
    --amp
# Out:
# [2026-09-21 00:07:33] [INFO] [downstream_3d]: Starting 3D Downstream Fine-Tuning: Model=visreg_jepa, Decoder=unetr_hybrid, FromScratch=True, FreezeEncoder=False
# [2026-09-21 00:07:34] [INFO] [downstream_3d]: Initializing 3D ViT-FPN from SCRATCH (random initialization, no pre-trained checkpoint) [--from_scratch active]
# Epoch 1/3: 100%|█████████████████| 572/572 [05:42<00:00,  1.67it/s, loss=0.6387]
# [2026-09-21 00:13:53] [INFO] [downstream_3d]: Epoch 1/3 - LR: 0.000300 | Train Loss: 0.8470 | Val Dice: 0.6476 | Val IoU: 0.5101
# [2026-09-21 00:13:54] [INFO] [downstream_3d]: New best model saved: /kaggle/working/outputs/checkpoints/visreg_jepa_unetr_hybrid_scratch_best.pt (Val Dice: 0.6476)
# Epoch 2/3: 100%|█████████████████| 572/572 [05:44<00:00,  1.66it/s, loss=0.8173]
# [2026-09-21 00:20:14] [INFO] [downstream_3d]: Epoch 2/3 - LR: 0.000150 | Train Loss: 0.5528 | Val Dice: 0.6929 | Val IoU: 0.5618
# [2026-09-21 00:20:15] [INFO] [downstream_3d]: New best model saved: /kaggle/working/outputs/checkpoints/visreg_jepa_unetr_hybrid_scratch_best.pt (Val Dice: 0.6929)
# Epoch 3/3: 100%|█████████████████| 572/572 [05:43<00:00,  1.66it/s, loss=0.2503]
# [2026-09-21 00:26:35] [INFO] [downstream_3d]: Epoch 3/3 - LR: 0.000001 | Train Loss: 0.3713 | Val Dice: 0.7724 | Val IoU: 0.6569
# [2026-09-21 00:26:36] [INFO] [downstream_3d]: New best model saved: /kaggle/working/outputs/checkpoints/visreg_jepa_unetr_hybrid_scratch_best.pt (Val Dice: 0.7724)
# [2026-09-21 00:26:37] [INFO] [downstream_3d]: 3D Downstream Fine-Tuning finished (from scratch).

# %% [markdown]
# ## 6. Held-Out Test Split Evaluation
# Evaluates the trained from-scratch 3D ViT-FPN model on the held-out test split ($N=242$ volumes) across:
# - Exact Volumetric 3D Dice Score (%)
# - Volumetric 3D IoU (%)
# - 95th Percentile Hausdorff Distance (HD95, mm)
# - Inference Latency (ms per volume)

# %%
# !python scripts/evaluate_3d.py \
    --model_type visreg_jepa \
    --decoder_type unetr_hybrid \
    --from_scratch \
    --seed {SEED} \
    --batch_size {BATCH_SIZE} \
    --num_workers {NUM_WORKERS} \
    --amp \
    --tta
# Out:
# [2026-09-21 00:27:02] [INFO] [evaluate_3d]: Initializing Master 3D Volumetric Benchmark...
# [2026-09-21 00:27:02] [INFO] [evaluate_3d]: TTA enabled: 4-fold orthogonal-reflection averaging (4x forward passes per volume).
# [2026-09-21 00:27:03] [INFO] [evaluate_3d]: Evaluating: 3D ViT-FPN (From Scratch) [unetr_hybrid]
# [2026-09-21 00:27:04] [INFO] [evaluate_3d]: Loaded downstream fine-tuned weights from visreg_jepa_unetr_hybrid_scratch_best.pt (169 matched keys)
#
#                                    Model      Dice (%)       IoU (%)     HD95 (mm) Latency (ms) EffRank (S²) Centered CosSim
# 3D ViT-FPN (From Scratch) [unetr_hybrid] 78.45 ± 13.95 66.36 ± 16.07 16.15 ± 18.69       949.56 13.37 (3.5%)          0.0340
#
# [2026-09-21 00:29:46] [INFO] [evaluate_3d]: Summary saved to /kaggle/working/outputs/metrics/benchmark_3d_summary.csv and /kaggle/working/outputs/metrics/master_3d_benchmark.csv

# %% [markdown]
# ## 7. Low-Data Volumetric Label Efficiency for 3D ViT-FPN (From Scratch)
# Evaluates fine-tuning performance across annotation budgets: $1\%$ ($11$ vols), $5\%$ ($57$ vols), $10\%$ ($114$ vols), $25\%$ ($286$ vols), $50\%$ ($572$ vols), and $100\%$ ($1,144$ vols) when trained from random initialization. This directly isolates the empirical representation gain of self-supervised JEPA pre-training.

# %%
# !python scripts/evaluate_low_data_3d.py \
    --model_type visreg_jepa \
    --decoder_type unetr_hybrid \
    --fractions 0.01 0.05 0.10 0.25 0.50 1.00 \
    --seed {SEED} \
    --epochs 3 \
    --batch_size {BATCH_SIZE} \
    --num_workers {NUM_WORKERS} \
    --amp \
    --from_scratch
# Out:
# [2026-09-21 00:30:09] [INFO] [low_data_3d]: Starting 3D Low-Data Label Efficiency Benchmark...
# [2026-09-21 00:30:09] [INFO] [low_data_3d]:
# --- Evaluating Fraction: 1.0% Labels ---
# [2026-09-21 00:30:09] [WARNING] [low_data_3d]: No pre-trained SSL weights found for 3D VisReg JEPA (FPN) (visreg_jepa_3d_best.pt / visreg_jepa*_epoch_*.pt). Skipping evaluation (will not train random uninitialized encoder on low data).
# [2026-09-21 00:30:10] [INFO] [low_data_3d]:
# --- Evaluating Fraction: 5.0% Labels ---
# [2026-09-21 00:30:10] [WARNING] [low_data_3d]: No pre-trained SSL weights found for 3D VisReg JEPA (FPN) (visreg_jepa_3d_best.pt / visreg_jepa*_epoch_*.pt). Skipping evaluation (will not train random uninitialized encoder on low data).
# [2026-09-21 00:30:10] [INFO] [low_data_3d]:
# --- Evaluating Fraction: 10.0% Labels ---
# [2026-09-21 00:30:10] [WARNING] [low_data_3d]: No pre-trained SSL weights found for 3D VisReg JEPA (FPN) (visreg_jepa_3d_best.pt / visreg_jepa*_epoch_*.pt). Skipping evaluation (will not train random uninitialized encoder on low data).
# [2026-09-21 00:30:11] [INFO] [low_data_3d]:
# --- Evaluating Fraction: 25.0% Labels ---
# [2026-09-21 00:30:11] [WARNING] [low_data_3d]: No pre-trained SSL weights found for 3D VisReg JEPA (FPN) (visreg_jepa_3d_best.pt / visreg_jepa*_epoch_*.pt). Skipping evaluation (will not train random uninitialized encoder on low data).
# [2026-09-21 00:30:11] [INFO] [low_data_3d]:
# --- Evaluating Fraction: 50.0% Labels ---
# [2026-09-21 00:30:11] [WARNING] [low_data_3d]: No pre-trained SSL weights found for 3D VisReg JEPA (FPN) (visreg_jepa_3d_best.pt / visreg_jepa*_epoch_*.pt). Skipping evaluation (will not train random uninitialized encoder on low data).
# [2026-09-21 00:30:11] [INFO] [low_data_3d]:
# --- Evaluating Fraction: 100.0% Labels ---
# [2026-09-21 00:30:12] [WARNING] [low_data_3d]: No pre-trained SSL weights found for 3D VisReg JEPA (FPN) (visreg_jepa_3d_best.pt / visreg_jepa*_epoch_*.pt). Skipping evaluation (will not train random uninitialized encoder on low data).
#
# Fraction 3D VisReg JEPA (FPN) [unetr_hybrid]
#     1.0%                                 N/A
#     5.0%                                 N/A
#    10.0%                                 N/A
#    25.0%                                 N/A
#    50.0%                                 N/A
#   100.0%                                 N/A
#
# [2026-09-21 00:30:12] [INFO] [low_data_3d]: Low-data summary saved to /kaggle/working/outputs/metrics/low_data_3d_summary.csv and /kaggle/working/outputs/metrics/low_data_3d_summary.md

# %% [markdown]
# ## 8. Out-of-Distribution (OOD) Scanner Shift Robustness for 3D ViT-FPN (From Scratch)
# Evaluates the trained from-scratch 3D ViT-FPN model under physical 3D Rician scanner noise ($\sigma=0.08$), quadratic RF $B_1$ field bias, and missing sequence triage (T1c-only, FLAIR-only). $B_1$ fields are per-sample random; Rician/B1 tissue models are sign-preserving (Rician-if-nonnegative / Gaussian-if-negative, gain on original voxels). OOD tables measured before the sign-preserving fix are **not comparable** — re-run evaluate_ood_3d.py; see README §6.3.

# %%
# !python scripts/evaluate_ood_3d.py \
    --model_type visreg_jepa \
    --decoder_type unetr_hybrid \
    --seed {SEED} \
    --batch_size 1 \
    --num_workers {NUM_WORKERS} \
    --amp \
    --from_scratch
# Out:
# [2026-09-21 00:30:35] [INFO] [evaluate_ood_3d]: Starting 3D Out-of-Distribution Scanner Shift Benchmark...
# [2026-09-21 00:30:35] [WARNING] [evaluate_ood_3d]: Checkpoint for 3D VisReg JEPA (FPN) not found. Skipping OOD evaluation.
# [2026-09-21 00:30:35] [INFO] [evaluate_ood_3d]:
# --- Evaluating Regime: Clean Baseline ---
# [2026-09-21 00:30:35] [INFO] [evaluate_ood_3d]:
# --- Evaluating Regime: Rician Noise (sigma=0.08) ---
# [2026-09-21 00:30:35] [INFO] [evaluate_ood_3d]:
# --- Evaluating Regime: B1 Bias Field Inhomogeneity ---
# [2026-09-21 00:30:35] [INFO] [evaluate_ood_3d]:
# --- Evaluating Regime: Missing Modalities: T1c Only ---
# [2026-09-21 00:30:35] [INFO] [evaluate_ood_3d]:
# --- Evaluating Regime: Missing Modalities: FLAIR Only ---
#
#                         Regime 3D VisReg JEPA (FPN) [unetr_hybrid]
#                 Clean Baseline                                 N/A
#      Rician Noise (sigma=0.08)                                 N/A
#    B1 Bias Field Inhomogeneity                                 N/A
#   Missing Modalities: T1c Only                                 N/A
# Missing Modalities: FLAIR Only                                 N/A
#
# [2026-09-21 00:30:35] [INFO] [evaluate_ood_3d]: OOD summary saved to /kaggle/working/outputs/metrics/ood_3d_summary.csv and /kaggle/working/outputs/metrics/ood_3d_summary.md

# %% [markdown]
# ## 9. Export & Package Artifacts
# Packages from-scratch 3D ViT-FPN checkpoints, training curves, and all evaluation benchmark summaries into `vit_scratch_outputs.zip`.

# %%
import datetime
import time
from pathlib import Path

from brats_jepa_3d.config import IN_KAGGLE, PROJECT_ROOT
from brats_jepa_3d.utils import export_artifacts

# 1. Package trained from-scratch ViT checkpoints, metrics, and logs into a verified zip archive
base_working = Path("/kaggle/working") if IN_KAGGLE else PROJECT_ROOT
export_res = export_artifacts(
    export_name="vit_scratch_outputs",
    export_dir=base_working / "export_vit_scratch",
    zip_path=base_working / "vit_scratch_outputs.zip",
    model_prefix="scratch",
    verbose=True,
)

# 2. Session Timing Report
NOTEBOOK_END_TIME = time.time()
NOTEBOOK_END_STR = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
start_time = globals().get("NOTEBOOK_START_TIME", NOTEBOOK_END_TIME)
total_elapsed_sec = NOTEBOOK_END_TIME - start_time
hours, rem = divmod(total_elapsed_sec, 3600)
minutes, seconds = divmod(rem, 60)

print("\n" + "=" * 50)
print(f"⏱️ Session Start Time:   {globals().get('NOTEBOOK_START_STR', 'N/A')}")
print(f"⏱️ Session End Time:     {NOTEBOOK_END_STR}")
print(f"⏱️ Total Execution Time: {int(hours)}h {int(minutes)}m {seconds:.2f}s ({total_elapsed_sec:.2f}s)")
print("=" * 50)
# Out:
# 📦 Packaging artifacts from outputs source: /kaggle/working/outputs
# 📁 Staging directory: /kaggle/working/export_vit_scratch
#
# ✓ Collected 14 artifact file(s) into /kaggle/working/export_vit_scratch:
#   • checkpoints/visreg_jepa_unetr_hybrid_scratch_best.pt (338.04 MB)
#   • checkpoints/visreg_jepa_unetr_hybrid_scratch_latest.pt (338.04 MB)
#   • metrics/benchmark_3d.log (0.00 MB)
#   • metrics/benchmark_3d_summary.csv (0.00 MB)
#   • metrics/benchmark_3d_summary.md (0.00 MB)
#   • metrics/low_data_3d_summary.csv (0.00 MB)
#   • metrics/low_data_3d_summary.md (0.00 MB)
#   • metrics/master_3d_benchmark.csv (0.00 MB)
#   • metrics/master_3d_benchmark.md (0.00 MB)
#   • metrics/ood_3d_summary.csv (0.00 MB)
#   • metrics/ood_3d_summary.md (0.00 MB)
#   • logs/visreg_jepa_unetr_hybrid_scratch_downstream.log (0.00 MB)
#   • logs/visreg_jepa_unetr_hybrid_scratch_downstream_metrics.csv (0.00 MB)
#   • logs/visreg_jepa_unetr_hybrid_scratch_downstream_metrics.json (0.00 MB)
# ✓ Found 2 checkpoint file(s).
#
# ✓ vit_scratch_outputs.zip created! Total archive size: 618.95 MB
# 📍 Archive path: /kaggle/working/vit_scratch_outputs.zip
#
# ==================================================
# ⏱️ Session Start Time:   2026-09-21 00:06:09
# ⏱️ Session End Time:     2026-09-21 00:31:13
# ⏱️ Total Execution Time: 0h 25m 4.47s (1504.47s)
# ==================================================
